# %%
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
import pandas as pd
from sklearn.preprocessing import StandardScaler

# %%
df = pd.read_csv("drug200.csv")
df
# Out:
#      Age Sex      BP Cholesterol  Na_to_K   Drug
# 0     23   F    HIGH        HIGH   25.355  DrugY
# 1     47   M     LOW        HIGH   13.093  drugC
# 2     47   M     LOW        HIGH   10.114  drugC
# 3     28   F  NORMAL        HIGH    7.798  drugX
# 4     61   F     LOW        HIGH   18.043  DrugY
# ..   ...  ..     ...         ...      ...    ...
# 195   56   F     LOW        HIGH   11.567  drugC
# 196   16   M     LOW        HIGH   12.006  drugC
# 197   52   M  NORMAL        HIGH    9.894  drugX
# 198   23   M  NORMAL      NORMAL   14.020  drugX
# 199   40   F     LOW      NORMAL   11.349  drugX
#
# [200 rows x 6 columns]

# %%
df["Drug"].unique()
# Out:
# array(['DrugY', 'drugC', 'drugX', 'drugA', 'drugB'], dtype=object)

# %%
df["Sex"] = df["Sex"].map({"M":1,"F":0})

df["Cholesterol"] = df["Cholesterol"].map({"HIGH":2,"NORMAL":1,"LOW":0})

df["BP"] = df["BP"].map({"HIGH":2,"NORMAL":1,"LOW":0})

# %%
df
# Out:
#      Age  Sex  BP  Cholesterol  Na_to_K   Drug
# 0     23    0   2            2   25.355  DrugY
# 1     47    1   0            2   13.093  drugC
# 2     47    1   0            2   10.114  drugC
# 3     28    0   1            2    7.798  drugX
# 4     61    0   0            2   18.043  DrugY
# ..   ...  ...  ..          ...      ...    ...
# 195   56    0   0            2   11.567  drugC
# 196   16    1   0            2   12.006  drugC
# 197   52    1   1            2    9.894  drugX
# 198   23    1   1            1   14.020  drugX
# 199   40    0   0            1   11.349  drugX
#
# [200 rows x 6 columns]

# %%
x = df[["Age","Sex","BP","Cholesterol","Na_to_K"]]

scalar = StandardScaler()

x_scaled = scalar.fit_transform(x)

model = KMeans(n_clusters=5,random_state=42)

model.fit_transform(x)

y_pred = model.labels_

print("k means labels ",y_pred)
# Out:
# k means labels  [3 2 2 3 1 3 2 0 1 0 2 0 0 1 2 3 1 0 3 0 4 4 4 2 0 3 0 2 0 2 3 1 2 4 2 2 0
#  0 0 3 1 1 2 3 2 1 0 1 3 3 4 1 4 3 1 3 1 0 1 0 0 3 1 2 1 4 3 3 4 3 1 3 3 0
#  0 3 0 3 3 0 1 1 0 0 2 1 2 1 0 2 1 0 3 0 2 0 4 4 3 3 0 2 3 2 3 0 3 0 1 3 2
#  2 0 1 3 2 1 0 0 4 3 3 0 0 2 3 1 0 4 0 1 4 2 3 0 1 2 0 2 1 2 4 1 1 0 1 0 3
#  1 3 2 1 2 1 0 2 0 4 1 0 0 2 2 3 3 0 4 2 4 3 3 2 0 0 0 1 2 3 0 1 3 1 3 0 3
#  4 1 2 4 1 4 3 1 1 4 2 3 2 3 0]

# %%
plt.figure(figsize=(11,8))

plt.scatter(x["Age"],x["Na_to_K"],c = y_pred)

plt.xlabel("feature 1")
plt.ylabel("feature 2")
# Out:
# Text(0, 0.5, 'feature 2')

# %%
df
# Out:
#      Age  Sex  BP  Cholesterol  Na_to_K   Drug
# 0     23    0   2            2   25.355  DrugY
# 1     47    1   0            2   13.093  drugC
# 2     47    1   0            2   10.114  drugC
# 3     28    0   1            2    7.798  drugX
# 4     61    0   0            2   18.043  DrugY
# ..   ...  ...  ..          ...      ...    ...
# 195   56    0   0            2   11.567  drugC
# 196   16    1   0            2   12.006  drugC
# 197   52    1   1            2    9.894  drugX
# 198   23    1   1            1   14.020  drugX
# 199   40    0   0            1   11.349  drugX
#
# [200 rows x 6 columns]

# %%
import numpy as np

# %%
sample = np.array([[23,0,2,2,25.355]])

sample_cluster = model.predict(sample)

plt.scatter(x["Age"], x["Na_to_K"], c=y_pred)
plt.scatter(sample[:,0], sample[:,4], marker="*", color="red", s=300)

plt.xlabel("Age")
plt.ylabel("Na_to_K")
plt.show()
# Out:
# e:\machine learnig\ml\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but KMeans was fitted with feature names
#   warnings.warn(
