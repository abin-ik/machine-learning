# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.linear_model import LinearRegression
from sklearn.metrics import root_mean_squared_error,r2_score
from sklearn.metrics import accuracy_score,confusion_matrix

# %%
df = pd.read_csv("sample_air_quality_data.csv")

# %%
df.isnull().sum()
# Out:
# Temperature    0
# Humidity       0
# PM2            0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
x = df[["Temperature","Humidity"]]

y = df["PM2"]

x_train,x_test,y_train,y_test = train_test_split(x , y , test_size= 0.2 , random_state= 42)

model = LinearRegression()

model.fit(x_train,y_train)

y_pred = model.predict(x_test)

print("root mean sqaured error",root_mean_squared_error(y_test,y_pred))
print("r2score",r2_score(y_test,y_pred))
# Out:
# root mean sqaured error 3.690857425211843
# r2score 0.9583793992443495

# %%
plt.scatter(x["Temperature"],y,color = "blue", label = "actual data")
plt.plot(x["Temperature"],y_pred, color="red", label="regression line")
plt.xlabel("temprature")
plt.title("LogisticRegression classification")
plt.grid()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[24], line 2
#       1 plt.scatter(x["Temperature"],y,color = "blue", label = "actual data")
# ----> 2 plt.plot(x["Temperature"],y_pred, color="red", label="regression line")
#       3 plt.xlabel("temprature")
#       4 plt.title("LogisticRegression classification")
#
# File e:\machine learnig\ml\Lib\site-packages\matplotlib\pyplot.py:3838, in plot(scalex, scaley, data, *args, **kwargs)
#    3830 @_copy_docstring_and_deprecators(Axes.plot)
#    3831 def plot(
#    3832     *args: float | ArrayLike | str,
#    (...)   3836     **kwargs,
#    3837 ) -> list[Line2D]:
# -> 3838     return gca().plot(
#    3839         *args,
#    3840         scalex=scalex,
#    3841         scaley=scaley,
#    3842         **({"data": data} if data is not None else {}),
#    3843         **kwargs,
#    3844     )
#
# ...
