# %%
import pandas as pd

# %%
df = pd.read_csv("healthcare-dataset-stroke-data.csv")
df
# Out:
#          id  gender   age  hypertension  heart_disease ever_married  \
# 0      9046    Male  67.0             0              1          Yes
# 1     51676  Female  61.0             0              0          Yes
# 2     31112    Male  80.0             0              1          Yes
# 3     60182  Female  49.0             0              0          Yes
# 4      1665  Female  79.0             1              0          Yes
# ...     ...     ...   ...           ...            ...          ...
# 5105  18234  Female  80.0             1              0          Yes
# 5106  44873  Female  81.0             0              0          Yes
# 5107  19723  Female  35.0             0              0          Yes
# 5108  37544    Male  51.0             0              0          Yes
# 5109  44679  Female  44.0             0              0          Yes
#
#           work_type Residence_type  avg_glucose_level   bmi   smoking_status  \
# 0           Private          Urban             228.69  36.6  formerly smoked
# 1     Self-employed          Rural             202.21   NaN     never smoked
# 2           Private          Rural             105.92  32.5     never smoked
# 3           Private          Urban             171.23  34.4           smokes
# 4     Self-employed          Rural             174.12  24.0     never smoked
# ...             ...            ...                ...   ...              ...
# 5105        Private          Urban              83.75   NaN     never smoked
# 5106  Self-employed          Urban             125.20  40.0     never smoked
# 5107  Self-employed          Rural              82.99  30.6     never smoked
# 5108        Private          Rural             166.29  25.6  formerly smoked
# 5109       Govt_job          Urban              85.28  26.2          Unknown
#
#       stroke
# 0          1
# 1          1
# 2          1
# 3          1
# 4          1
# ...      ...
# 5105       0
# 5106       0
# 5107       0
# 5108       0
# 5109       0
#
# [5110 rows x 12 columns]

# %%
df.isnull().sum()
# Out:
# id                     0
# gender                 0
# age                    0
# hypertension           0
# heart_disease          0
# ever_married           0
# work_type              0
# Residence_type         0
# avg_glucose_level      0
# bmi                  201
# smoking_status         0
# stroke                 0
# dtype: int64

# %%
df = df.dropna()

df.isnull().sum()
# Out:
# id                   0
# gender               0
# age                  0
# hypertension         0
# heart_disease        0
# ever_married         0
# work_type            0
# Residence_type       0
# avg_glucose_level    0
# bmi                  0
# smoking_status       0
# stroke               0
# dtype: int64

# %%
df
# Out:
#          id  gender   age  hypertension  heart_disease ever_married  \
# 0      9046    Male  67.0             0              1          Yes
# 2     31112    Male  80.0             0              1          Yes
# 3     60182  Female  49.0             0              0          Yes
# 4      1665  Female  79.0             1              0          Yes
# 5     56669    Male  81.0             0              0          Yes
# ...     ...     ...   ...           ...            ...          ...
# 5104  14180  Female  13.0             0              0           No
# 5106  44873  Female  81.0             0              0          Yes
# 5107  19723  Female  35.0             0              0          Yes
# 5108  37544    Male  51.0             0              0          Yes
# 5109  44679  Female  44.0             0              0          Yes
#
#           work_type Residence_type  avg_glucose_level   bmi   smoking_status  \
# 0           Private          Urban             228.69  36.6  formerly smoked
# 2           Private          Rural             105.92  32.5     never smoked
# 3           Private          Urban             171.23  34.4           smokes
# 4     Self-employed          Rural             174.12  24.0     never smoked
# 5           Private          Urban             186.21  29.0  formerly smoked
# ...             ...            ...                ...   ...              ...
# 5104       children          Rural             103.08  18.6          Unknown
# 5106  Self-employed          Urban             125.20  40.0     never smoked
# 5107  Self-employed          Rural              82.99  30.6     never smoked
# 5108        Private          Rural             166.29  25.6  formerly smoked
# 5109       Govt_job          Urban              85.28  26.2          Unknown
#
#       stroke
# 0          1
# 2          1
# 3          1
# 4          1
# 5          1
# ...      ...
# 5104       0
# 5106       0
# 5107       0
# 5108       0
# 5109       0
#
# [4909 rows x 12 columns]

# %%
df["smoking_status"].unique()
# Out:
# array(['formerly smoked', 'never smoked', 'smokes', 'Unknown'],
#       dtype=object)

# %%
df = df[df["smoking_status"] != "Unknown"]
df
# Out:
#          id  gender   age  hypertension  heart_disease ever_married  \
# 0      9046    Male  67.0             0              1          Yes
# 2     31112    Male  80.0             0              1          Yes
# 3     60182  Female  49.0             0              0          Yes
# 4      1665  Female  79.0             1              0          Yes
# 5     56669    Male  81.0             0              0          Yes
# ...     ...     ...   ...           ...            ...          ...
# 5100  68398    Male  82.0             1              0          Yes
# 5102  45010  Female  57.0             0              0          Yes
# 5106  44873  Female  81.0             0              0          Yes
# 5107  19723  Female  35.0             0              0          Yes
# 5108  37544    Male  51.0             0              0          Yes
#
#           work_type Residence_type  avg_glucose_level   bmi   smoking_status  \
# 0           Private          Urban             228.69  36.6  formerly smoked
# 2           Private          Rural             105.92  32.5     never smoked
# 3           Private          Urban             171.23  34.4           smokes
# 4     Self-employed          Rural             174.12  24.0     never smoked
# 5           Private          Urban             186.21  29.0  formerly smoked
# ...             ...            ...                ...   ...              ...
# 5100  Self-employed          Rural              71.97  28.3     never smoked
# 5102        Private          Rural              77.93  21.7     never smoked
# 5106  Self-employed          Urban             125.20  40.0     never smoked
# 5107  Self-employed          Rural              82.99  30.6     never smoked
# 5108        Private          Rural             166.29  25.6  formerly smoked
#
#       stroke
# 0          1
# 2          1
# 3          1
# 4          1
# 5          1
# ...      ...
# 5100       0
# 5102       0
# 5106       0
# 5107       0
# 5108       0
#
# [3426 rows x 12 columns]

# %%
df["gender"] = df["gender"].map({"Male":1,"Female":0})
df["smoking_status"] = df["smoking_status"].map({"never smoked":0, "formerly smoked":1, "smokes":2})
df["work_type"] = df["work_type"].map({
    "Private": 0,
    "Self-employed": 1,
    "Govt_job": 2,
    "children": 3,
    "Never_worked": 4
})
df["Residence_type"] = df["Residence_type"].map({"Urban": 0, "Rural": 1})

df["ever_married"] = df["ever_married"].map({"No": 0, "Yes": 1})
# Out:
# C:\Users\91859\AppData\Local\Temp\ipykernel_16012\574952166.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["gender"] = df["gender"].map({"Male":1,"Female":0})
# C:\Users\91859\AppData\Local\Temp\ipykernel_16012\574952166.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["smoking_status"] = df["smoking_status"].map({"never smoked":0, "formerly smoked":1, "smokes":2})
# C:\Users\91859\AppData\Local\Temp\ipykernel_16012\574952166.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["work_type"] = df["work_type"].map({
# C:\Users\91859\AppData\Local\Temp\ipykernel_16012\574952166.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Residence_type"] = df["Residence_type"].map({"Urban": 0, "Rural": 1})
# C:\Users\91859\AppData\Local\Temp\ipykernel_16012\574952166.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["ever_married"] = df["ever_married"].map({"No": 0, "Yes": 1})

# %%
df["ever_married"].unique()
# Out:
# array([1, 0])

# %%
df
# Out:
#          id  gender   age  hypertension  heart_disease  ever_married  \
# 0      9046     1.0  67.0             0              1             1
# 2     31112     1.0  80.0             0              1             1
# 3     60182     0.0  49.0             0              0             1
# 4      1665     0.0  79.0             1              0             1
# 5     56669     1.0  81.0             0              0             1
# ...     ...     ...   ...           ...            ...           ...
# 5100  68398     1.0  82.0             1              0             1
# 5102  45010     0.0  57.0             0              0             1
# 5106  44873     0.0  81.0             0              0             1
# 5107  19723     0.0  35.0             0              0             1
# 5108  37544     1.0  51.0             0              0             1
#
#       work_type  Residence_type  avg_glucose_level   bmi  smoking_status  \
# 0             0               0             228.69  36.6               1
# 2             0               1             105.92  32.5               0
# 3             0               0             171.23  34.4               2
# 4             1               1             174.12  24.0               0
# 5             0               0             186.21  29.0               1
# ...         ...             ...                ...   ...             ...
# 5100          1               1              71.97  28.3               0
# 5102          0               1              77.93  21.7               0
# 5106          1               0             125.20  40.0               0
# 5107          1               1              82.99  30.6               0
# 5108          0               1             166.29  25.6               1
#
#       stroke
# 0          1
# 2          1
# 3          1
# 4          1
# 5          1
# ...      ...
# 5100       0
# 5102       0
# 5106       0
# 5107       0
# 5108       0
#
# [3426 rows x 12 columns]

# %%
from sklearn.metrics import  accuracy_score
from sklearn.neighbors import KNeighborsClassifier

from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
from sklearn.metrics import root_mean_squared_error,r2_score

# %%
df
# Out:
#          id  gender   age  hypertension  heart_disease  ever_married  \
# 0      9046     1.0  67.0             0              1             1
# 2     31112     1.0  80.0             0              1             1
# 3     60182     0.0  49.0             0              0             1
# 4      1665     0.0  79.0             1              0             1
# 5     56669     1.0  81.0             0              0             1
# ...     ...     ...   ...           ...            ...           ...
# 5100  68398     1.0  82.0             1              0             1
# 5102  45010     0.0  57.0             0              0             1
# 5106  44873     0.0  81.0             0              0             1
# 5107  19723     0.0  35.0             0              0             1
# 5108  37544     1.0  51.0             0              0             1
#
#       work_type  Residence_type  avg_glucose_level   bmi  smoking_status  \
# 0             0               0             228.69  36.6               1
# 2             0               1             105.92  32.5               0
# 3             0               0             171.23  34.4               2
# 4             1               1             174.12  24.0               0
# 5             0               0             186.21  29.0               1
# ...         ...             ...                ...   ...             ...
# 5100          1               1              71.97  28.3               0
# 5102          0               1              77.93  21.7               0
# 5106          1               0             125.20  40.0               0
# 5107          1               1              82.99  30.6               0
# 5108          0               1             166.29  25.6               1
#
#       stroke
# 0          1
# 2          1
# 3          1
# 4          1
# 5          1
# ...      ...
# 5100       0
# 5102       0
# 5106       0
# 5107       0
# 5108       0
#
# [3426 rows x 12 columns]

# %%
df.columns
# Out:
# Index(['id', 'gender', 'age', 'hypertension', 'heart_disease', 'ever_married',
#        'work_type', 'Residence_type', 'avg_glucose_level', 'bmi',
#        'smoking_status', 'stroke'],
#       dtype='object')

# %%
df = df.dropna().reset_index(drop=True)

# %%
x = df[['gender', 'age', 'hypertension', 'heart_disease', 'ever_married',
       'work_type', 'Residence_type', 'avg_glucose_level', 'bmi',
       'smoking_status']]

y = df["stroke"]

# %%
x_trian,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=42)

model = KNeighborsClassifier(n_neighbors=5)

model.fit(x_trian,y_train)

y_pred = model.predict(x_test)

print("accuraxy_score",accuracy_score(y_test,y_pred))
print("root_square_mean_error",root_mean_squared_error(y_test,y_pred))
# Out:
# accuraxy_score 0.9240875912408759
# root_square_mean_error 0.27552206582980626

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score,confusion_matrix

# %%
model1 = LogisticRegression()

model1.fit(x_trian,y_train)

y_pred1 = model1.predict(x_test)

print("accuraxy_score",accuracy_score(y_test,y_pred1))
print("confusion_matrix\n",confusion_matrix(y_test,y_pred1))
print("root_square_mean_error",root_mean_squared_error(y_test,y_pred1))
# Out:
# e:\machine learnig\ml\Lib\site-packages\sklearn\linear_model\_logistic.py:473: ConvergenceWarning: lbfgs failed to converge after 100 iteration(s) (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT
#
# Increase the number of iterations to improve the convergence (max_iter=100).
# You might also want to scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# accuraxy_score 0.9343065693430657
# confusion_matrix
#  [[640   1]
#  [ 44   0]]
# root_square_mean_error 0.25630729731502827

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import root_mean_squared_error,r2_score

# %%
model2 = RandomForestClassifier(n_estimators=100)

model2.fit(x_trian,y_train)

y_pred2 = model2.predict(x_test)

print("accuracy_score",accuracy_score(y_test,y_pred2))
print("r2_score",r2_score(y_test,y_pred2))
print("confusion_matrix\n",confusion_matrix(y_test,y_pred2))
print("root_square_mean_error",root_mean_squared_error(y_test,y_pred2))
# Out:
# accuracy_score 0.9313868613138686
# r2_score -0.14150475109913452
# confusion_matrix
#  [[638   3]
#  [ 44   0]]
# root_square_mean_error 0.2619410977417087

# %%
df
# Out:
#          id  gender   age  hypertension  heart_disease  ever_married  \
# 0      9046     1.0  67.0             0              1             1
# 1     31112     1.0  80.0             0              1             1
# 2     60182     0.0  49.0             0              0             1
# 3      1665     0.0  79.0             1              0             1
# 4     56669     1.0  81.0             0              0             1
# ...     ...     ...   ...           ...            ...           ...
# 3420  68398     1.0  82.0             1              0             1
# 3421  45010     0.0  57.0             0              0             1
# 3422  44873     0.0  81.0             0              0             1
# 3423  19723     0.0  35.0             0              0             1
# 3424  37544     1.0  51.0             0              0             1
#
#       work_type  Residence_type  avg_glucose_level   bmi  smoking_status  \
# 0             0               0             228.69  36.6               1
# 1             0               1             105.92  32.5               0
# 2             0               0             171.23  34.4               2
# 3             1               1             174.12  24.0               0
# 4             0               0             186.21  29.0               1
# ...         ...             ...                ...   ...             ...
# 3420          1               1              71.97  28.3               0
# 3421          0               1              77.93  21.7               0
# 3422          1               0             125.20  40.0               0
# 3423          1               1              82.99  30.6               0
# 3424          0               1             166.29  25.6               1
#
#       stroke
# 0          1
# 1          1
# 2          1
# 3          1
# 4          1
# ...      ...
# 3420       0
# 3421       0
# 3422       0
# 3423       0
# 3424       0
#
# [3425 rows x 12 columns]

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score,confusion_matrix

# %%
model3 = DecisionTreeClassifier()
model3.fit(x_trian,y_train)
y_pred3 = model1.predict(x_test)

print("accuracy_score",accuracy_score(y_test,y_pred3))
print("root_square_mean_error",root_mean_squared_error(y_test,y_pred3))
# Out:
# accuracy_score 0.9343065693430657
# root_square_mean_error 0.25630729731502827

# %%
new = [[1.0,57,0,1,0,2,1,444,67,1]]

new_data = model2.predict(new)

print("Prediction:", "Stroke" if new_data[0] == 0 else "No Stroke")
# Out:
# Prediction: Stroke
# e:\machine learnig\ml\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(

# %%
plt.scatter(y_test,y_pred2, c= y_test)
plt.legend()
plt.show()
# Out:
# C:\Users\91859\AppData\Local\Temp\ipykernel_16012\267002577.py:2: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()
