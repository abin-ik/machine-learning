# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score,confusion_matrix

# %%
data = {
    "study_hours" : [2,3,4,6,7,8],
    "attendance" : [60,65,70,75,80,85],
    "passed" : [0,0,0,1,1,1]
}

df = pd.DataFrame(data)

x = df[["study_hours","attendance"]]
y = df["passed"]

x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=42)
model = DecisionTreeClassifier()
model.fit(x_train,y_train)
y_pred = model.predict(x_test)

print("accuracy_score",accuracy_score(y_test,y_pred))
# Out:
# accuracy_score 1.0

# %%
plt.scatter(df["study_hours"],df["passed"])
plt.xlabel("study_hours")
plt.ylabel("passed(0 = no, 1 = yes)")
plt.title("LogisticRegression classification")
plt.grid()
plt.show()

# %%
new = [[9,90]]
prediction = model.predict(new)
print("passsed[1] or failed [0] :",prediction[0])
# Out:
# passsed[1] or failed [0] : 1
# e:\machine learnig\ml\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
