# %%
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import root_mean_squared_error,r2_score

# %%
data = {
    "experience" : [1,2,3,4,5,6],
    'salary':[3.2,4.0,4.7,5.5,6.3,7.1]
}

# %%
df = pd.DataFrame(data)
x = df[["experience"]]
y= df["salary"]
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=42)
model = LinearRegression()
model.fit(x_train,y_train)

y_pred = model.predict(x_test)

print("root_mean_squared_error",root_mean_squared_error(y_test,y_pred))
print("r2_score",r2_score(y_test,y_pred))


years  = 4.5
new_data = pd.DataFrame({"experience":[years]})
predicted_score = model.predict(new_data)
print(f"experience {years} have salary of {predicted_score}")
# Out:
# root_mean_squared_error 0.09999999999999876
# r2_score 0.9375000000000016
# experience 4.5 have salary of [5.9]

# %%
plt.scatter(x,y,color = "red",label = "actual data")
plt.plot(x,model.predict(x),color = "black",label = "regression line")
plt.xlabel("experience")
plt.ylabel("salary")
plt.title("experience vs salary")
plt.legend()
plt.show()
